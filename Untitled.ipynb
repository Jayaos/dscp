# %%
from utils import *
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_data(data_dir):
    file = open(data_dir,'rb')
    
    return pickle.load(file)

# %%
kowcpi_sim_data = load_data("C:/Users/jayao/Desktop/python_projects/DSCP/data/kowcpi_sim_data.pkl")

# %%
kowcpi_sim_data["kowcpi_sim"].keys()
# Out:
# dict_keys(['train_x', 'heldout_x', 'train_y', 'heldout_y', 'heldout_predictions'])

# %%
plt.plot(kowcpi_sim_data["kowcpi_sim"]["heldout_predictions"] - kowcpi_sim_data["kowcpi_sim"]["heldout_y"])
