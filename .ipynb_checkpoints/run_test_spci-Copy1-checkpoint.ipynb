# %%
from omegaconf import OmegaConf
import os
import copy
import torch
import numpy as np
from tqdm import tqdm
from sklearn_quantile import RandomForestQuantileRegressor, SampleRandomForestQuantileRegressor
from dscp.data import ConformalPredictionData
from utils.utils import load_data, save_data, read_setup, flatten_and_sort
from utils.utils import compute_coverage, compute_interval_width, compute_winkler_score

# %%
config = OmegaConf.load("C:/Users/jayao/Desktop/python_projects/DSCP/config/spci_config.yaml")

# %%
os.makedirs(config.saving_dir, exist_ok=True)

# %%
    # load data
    data = load_data(config.data.data_path) # load predictor results here
    base_predictor, data_type = read_setup(config.data.data_path)
    cpd = ConformalPredictionData(data)
    cpd.prepare_quantile_prediction_datasets(config.model.window_size, 
                             config.model.prediction_step, 
                             config.data.train_ratio, 
                             config.data.valid_ratio, 
                             config.data.normalize)

# %%
    print("Experiment setup")
    print("Method: SPCI")
    print("Base predictor: {}".format(base_predictor))
    print("Data: {}".format(data_type))
    print("{} independent sequences".format(len(cpd.dataset)))
# Out:
# Experiment setup
# Method: SPCI
# Base predictor: lr
# Data: toy
# 1 independent sequences

# %%
key, item = next(iter(cpd.dataset.items()))

# %%
target_quantiles = np.array(flatten_and_sort(config.model.target_quantiles))

# %%
target_quantiles
# Out:
# array([0.05, 0.95])

# %%
        # SPCI does not need validation set, therefore combine train and validation set
        train_dataset = item["train_dataset"]
        valid_dataset = item["valid_dataset"]
        test_dataset = item["test_dataset"]
        train_strided_feature, train_strided_residual, train_residual_target, train_y_true, train_preds = train_dataset[:]
        valid_strided_feature, valid_strided_residual, valid_residual_target, valid_y_true, valid_preds = valid_dataset[:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 5
#       3 valid_dataset = item["valid_dataset"]
#       4 test_dataset = item["test_dataset"]
# ----> 5 train_strided_feature, train_strided_residual, train_residual_target, train_y_true, train_preds = train_dataset[:]
#       6 valid_strided_feature, valid_strided_residual, valid_residual_target, valid_y_true, valid_preds = valid_dataset[:]
#
# ValueError: too many values to unpack (expected 5)

# %%
        strided_residual = torch.cat([train_strided_residual, valid_strided_residual], dim=0).numpy() # (data_size, window_size)
        residual_target = torch.cat([train_residual_target, valid_residual_target], dim=0).flatten().numpy() # (data_size, 1)

# %%
            qrf = SampleRandomForestQuantileRegressor(n_estimators=config.model.n_estimators,
                                                      max_depth=config.model.max_depth,
                                                      criterion=config.model.criterion,
                                                      n_jobs=-1,
                                                      q=target_quantiles)

# %%
qrf.fit(strided_residual, residual_target.flatten())
# Out:
# Sampling trees
# SampleRandomForestQuantileRegressor(max_depth=2, n_estimators=10, n_jobs=-1,
#                                     q=array([0.035, 0.05 , 0.95 , 0.965]))

# %%
        # predict residuals using the trained Quantile Random Forest
        test_strided_feature, test_strided_residual, test_residual_target, test_y_true, test_preds = test_dataset[:]
        pred_quantile_value = qrf.predict(test_strided_residual.numpy()) # (len(target_quantiles), test_size)

# %%
pred_quantile_value
# Out:
# array([[-46.95076872, -46.95076872, -46.95076872, ..., -42.70222212,
#         -85.86829205, -85.86829205],
#        [-46.68369843, -46.68369843, -46.68369843, ..., -40.61434585,
#         -85.61480137, -85.61480137],
#        [ 29.26416008,  29.26416008,  29.26416008, ...,  29.26416008,
#         -21.25062474, -21.25062474],
#        [ 33.73065603,  33.73065603,  33.73065603, ...,  33.73065603,
#         -20.9708418 , -20.9708418 ]], shape=(4, 3142))

# %%
evaluation_results = dict()

# %%
        for i in range(len(config.model.target_quantiles)):
            confidence_pair = (float(target_quantiles[-(i+1)]), float(target_quantiles[i]))
            evaluation_results[confidence_pair] = {"coverage": [], 
                                                   "interval_width": [],
                                                   "winkler_score" : [],
                                                   "upper_interval" : [],
                                                   "lower_interval" : []}

# %%
            lo = pred_quantile_value[i, :] # (batch_size,)
            hi = pred_quantile_value[-(i+1), :] # (batch_size,)

# %%
def compute_coverage_(upper_interval, lower_interval, target):

    if type(upper_interval) == np.ndarray:
        upper_interval = torch.from_numpy(upper_interval)

    if type(lower_interval) == np.ndarray:
        lower_interval = torch.from_numpy(lower_interval)

    if target.ndim == 2:
        target = target.flatten()

    upper_tf = (target <= upper_interval)
    lower_tf = (target >= lower_interval)
    coverage_tf = upper_tf * lower_tf

    return coverage_tf.detach().cpu().tolist()

# %%
def compute_interval_width_(upper_interval, lower_interval, normalized_std=None):
    """
    if normalized_params are given, compute interval width 
    """

    if type(upper_interval) == np.ndarray:
        upper_interval = torch.from_numpy(upper_interval)

    if type(lower_interval) == np.ndarray:
        lower_interval = torch.from_numpy(lower_interval)

    if normalized_std:
        interval_width = (upper_interval - lower_interval) * normalized_std
    else:
        interval_width = upper_interval - lower_interval

    return interval_width.detach().cpu().tolist()

# %%
this_coverage = compute_coverage_(hi, lo, test_residual_target)

# %%
            this_interval_width = compute_interval_width_(hi, lo, 
                                                         normalized_std=None)
