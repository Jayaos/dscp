# %%
from baselines.hopcpt.run_hopcpt import run_hopcpt, run_hopcpt_max_memory

# %%
run_hopcpt_max_memory("C:/Users/jayao/Desktop/python_projects/DSCP/config/hopcpt_config.yaml")
# Out:
# Experiment setup
# Method: HopCPT
# Base predictor: ridge
# Data: toy
# 0 independent sequences
# ...
# training epochs:   0%|                                                                        | 0/2000 [00:00<?, ?it/s]C:\Users\jayao\Desktop\python_projects\virtual_envs\hopcpt\lib\site-packages\torch\nn\_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
#
# training epochs:   0%|                                                              | 1/2000 [00:04<2:30:18,  4.51s/it]
# training loss at epoch 1: 16549.12109375
# training loss at epoch 2: 16383.4521484375
# training loss at epoch 3: 16218.78515625
# training loss at epoch 4: 16054.607421875
# training loss at epoch 5: 15890.12109375
# torch.Size([1, 234, 2])
# torch.Size([1, 235, 2])
# torch.Size([1, 236, 2])
# torch.Size([1, 237, 2])
# torch.Size([1, 238, 2])
# torch.Size([1, 239, 2])
# torch.Size([1, 240, 2])
# ...
